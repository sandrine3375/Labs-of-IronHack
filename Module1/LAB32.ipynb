# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
data_ori=pd.read_excel(r"C:\Users\Lenovo\Documents\Ironhack\DATA\example_data_cleaning.xlsx")
data= data_ori.copy()
data.head()
# Out:
#    TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 0              1     34982     2013.0   12900    Student          78     Low
# 1              2     34983     2015.0    1230     barmen          78    High
# 2              3     34984     1945.0    3450    student          78  Medium
# 3              4     34985     1923.0    5670    manager          78     Low
# 4              5     34986     1978.0    7890         hr          78    High

# %%
data.describe()
# Out:
#        TransactionID      ClientID    BirthYear        Amount  Department
# count      30.000000     30.000000    28.000000  3.000000e+01        30.0
# mean       15.500000  34993.833333  1968.316327  1.010097e+05        78.0
# std         8.803408      8.132876    27.963867  4.342616e+05         0.0
# min         1.000000  34982.000000  1923.000000  1.230000e+03        78.0
# 25%         8.250000  34987.250000  1944.714286  1.233000e+04        78.0
# 50%        15.500000  34991.500000  1967.000000  1.899000e+04        78.0
# 75%        22.750000  34999.750000  1988.000000  2.953500e+04        78.0
# max        30.000000  35008.000000  2017.000000  2.399090e+06        78.0

# %%
#to see null value
data.isna().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        2
# Amount           0
# Profession       2
# Department       0
# Risk             0
# dtype: int64

# %%
data.dropna(axis='rows', inplace=True) #supprimer rows avec nuL

# %%
# autre possibilité: inclure données
data.at[7,'BirthYear']=1967
data.at[8,'BirthYear']=1999

# %%
data.isna().sum()
# Out:
# TransactionID    0
# ClientID         0
# BirthYear        0
# Amount           0
# Profession       0
# Department       0
# Risk             0
# dtype: int64

# %%
data ['Profession'].replace ('student', 'Student', inplace=True)

# %%
data ['Profession'].replace ('etudient', 'Student', inplace=True)

# %%
data['Profession'] = data['Profession'].str.upper() #mettre tout en majuscule

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               1     34982  2013.000000    12900      STUDENT          78
# 1               2     34983  2015.000000     1230       BARMEN          78
# 2               3     34984  1945.000000     3450      STUDENT          78
# 3               4     34985  1923.000000     5670      MANAGER          78
# 4               5     34986  1978.000000     7890           HR          78
# 5               6     34987  1967.000000    10110      MANAGER          78
# 6              15     34987  1967.000000    30090      MANAGER          78
# 9              23     34988  1999.000000    25650      MANAGER          78
# 10              8     34989  1958.000000    14550           HR          78
# 11             24     34989  1967.000000    27870           HR          78
# 12              9     34990  1953.285714    16770      MANAGER          78
# ...

# %%
#supprimer le row birtday 2017 (index13): 
data.drop(13, inplace=True)

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear   Amount   Profession  Department  \
# 0               1     34982  2013.000000    12900      STUDENT          78
# 1               2     34983  2015.000000     1230       BARMEN          78
# 2               3     34984  1945.000000     3450      STUDENT          78
# 3               4     34985  1923.000000     5670      MANAGER          78
# 4               5     34986  1978.000000     7890           HR          78
# 5               6     34987  1967.000000    10110      MANAGER          78
# 6              15     34987  1967.000000    30090      MANAGER          78
# 9              23     34988  1999.000000    25650      MANAGER          78
# 10              8     34989  1958.000000    14550           HR          78
# 11             24     34989  1967.000000    27870           HR          78
# 12              9     34990  1953.285714    16770      MANAGER          78
# ...

# %%
#to check outlier
plt.figure(figsize=(10, 6))
data['Profession'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
cat_col = data.select_dtypes(include=['object'])
num_col = data.select_dtypes(exclude=['object'])
def printColumnTypes(non_numeric_df, numeric_df):
    '''separates non-numeric and numeric columns'''
    print("Non-Numeric columns:")
    for col in non_numeric_df:
        print(f"{col}")
    print("")
    print("Numeric columns:")
    for col in numeric_df:
        print(f"{col}")

# %%
printColumnTypes(cat_col, num_col)
# Out:
# Non-Numeric columns:
# Profession
# Risk
#
# Numeric columns:
# TransactionID
# ClientID
# BirthYear
# Amount
# Department

# %%
# encoding profession and risk
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['Profession_encode']=encoder.fit_transform(data['Profession'])
data['Risk_encode']=encoder.fit_transform(data['Risk'])
data=data.drop(columns=['Profession', 'Risk'])

# %%
data
# Out:
#     TransactionID  ClientID    BirthYear   Amount  Department  \
# 0               1     34982  2013.000000    12900          78
# 1               2     34983  2015.000000     1230          78
# 2               3     34984  1945.000000     3450          78
# 3               4     34985  1923.000000     5670          78
# 4               5     34986  1978.000000     7890          78
# 5               6     34987  1967.000000    10110          78
# 6              15     34987  1967.000000    30090          78
# 9              23     34988  1999.000000    25650          78
# 10              8     34989  1958.000000    14550          78
# 11             24     34989  1967.000000    27870          78
# 12              9     34990  1953.285714    16770          78
# 14             30     34991  1988.000000    55250          78
# 15             11     34992  1943.857143    21210          78
# 16             12     34993  1939.142857    23430          78
# ...
