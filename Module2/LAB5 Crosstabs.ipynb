# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 1. Import the moovies dataset

# %% [markdown]
# # https://www.kaggle.com/carolzhangdc/imdb-5000-movie-dataset

# %%
data = pd.read_csv(r'C:\Users\Lenovo\Documents\Ironhack\DATA\movie_metadata.csv')
data.shape
data
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# ### 2. Use crosstabs to show the number of moovies per country

# %%
pd.crosstab(data['country'], data['genres'].count())
# Out:
# col_0                 5043
# country
# Afghanistan              1
# Argentina                4
# Aruba                    1
# Australia               55
# Bahamas                  1
# ...                    ...
# Turkey                   1
# UK                     448
# USA                   3807
# United Arab Emirates     1
# West Germany             3
#
# [65 rows x 1 columns]

# %% [markdown]
# ### 3. Create a crosstab to show the number of films per director and genre splitted by country

# %%
pd.crosstab( data['country'], [data['director_name'], data['genres']])
# Out:
# director_name                                 A. Raven Cruz  \
# genres               Action|Adventure|Comedy|Fantasy|Sci-Fi
# country
# Afghanistan                                               0
# Argentina                                                 0
# Aruba                                                     0
# Australia                                                 0
# Bahamas                                                   0
# ...                                                     ...
# Turkey                                                    0
# UK                                                        0
# USA                                                       1
# United Arab Emirates                                      0
# West Germany                                              0
#
# director_name                                  Aaron Hann Aaron Schneider  \
# genres               Drama|Horror|Mystery|Sci-Fi|Thriller   Drama|Mystery
# country
# ...

# %% [markdown]
# ### 4. Average duration of filmes grouped by color

# %%
data['duration'].groupby(data['color']).mean()
# Out:
# color
#  Black and White    112.253589
# Color               107.042908
# Name: duration, dtype: float64

# %% [markdown]
# ### 5. Average number of likes per director (assuming that total film's likes are counted as a sum of actor's likes)

# %%
data['movie_facebook_likes'].groupby(data['director_name']).mean()
# Out:
# director_name
# A. Raven Cruz         128.0
# Aaron Hann              0.0
# Aaron Schneider         0.0
# Aaron Seltzer         806.0
# Abel Ferrara          344.0
#                       ...
# Zoran Lisinac         231.0
# Álex de la Iglesia      0.0
# Émile Gaudreault      352.0
# Éric Tessier           39.0
# Étienne Faure         114.0
# Name: movie_facebook_likes, Length: 2398, dtype: float64

# %%
pd.crosstab( data['director_name'], data['movie_facebook_likes'], aggfunc=np.average)
