# %%
#CHALLENT ONE

# %%
x = 'Ironhack'
import math
math.factorial(len(x))
# Out:
# 40320

# %%
from itertools import permutations
perms = [''.join(p) for p in permutations(x)]


set(perms) #not to have duplicate
# Out:
# {'roaIcknh',
#  'okaIrcnh',
#  'Iohckrna',
#  'Inrkhoca',
#  'nIachkro',
#  'hnrkcIoa',
#  'nIhkorac',
#  'cIrahonk',
#  'ohnIacrk',
#  'kachnoIr',
#  'Iahrknco',
#  'raocnIkh',
#  'anhcIkro',
#  'crkaonhI',
#  'anIcrokh',
#  'cohIarkn',
#  'hocnIkar',
#  'Ichaokrn',
#  'Ichnakor',
#  'akIhcnor',
#  'hrIkcona',
#  'rnkIaohc',
#  'nkhacorI',
#  'onIhackr',
#  'nhkorcaI',
#  'Irchkona',
#  'coIkarnh',
#  'hnrcokaI',
#  'oIkrhcan',
#  'okcnIahr',
#  'ocaIrhkn',
#  'cIoahknr',
#  'conahkrI',
#  'rhocInak',
#  'rcokhanI',
#  'naIhrcko',
#  'nhrakoIc',
#  'Icrakhno',
#  'nkohracI',
#  'rocankhI',
#  'nrhocakI',
#  'rcInhaok',
#  'cIhknaro',
#  'nIaohrkc',
#  'akorIcnh',
#  'Ihnkoacr',
#  'rhcknaIo',
#  'Iackhron',
#  'nrakhoIc',
#  'hocnIark',
#  'Ichnroka',
#  'norkIcah',
#  'ahkrnIco',
#  'arhoInck',
#  'kronIahc',
#  'nckhaoIr',
#  'nckraoIh',
#  'ncoIrhka',
#  'cnrhIoka',
#  'achorInk',
#  'crakoIhn',
#  'rnIchaok',
#  'rIhnkaoc',
#  'rIaonkch',
#  'Inrhkcoa',
#  'nohacIkr',
# ...

# %%
#CHALLENGE 2

# %% [markdown]
# There is 17*16*15 possibilities ( we choose one student only one time)
# and we divide by 2*3 to delete the duplicate
# So it is: 17*8*5

# %%
#challenge 3

# %% [markdown]
# there is 10*10*10*10*10 possibilities ( any ingredient can be choose many times)
# and we divide by 2*3*4*5 to delete the duplicate ( for exemple if x ingregient is choose first in the first recipie, it can be choose last in the same recipies in an other draw)

# %%
#challenge 4

# %%
import random
import numpy as np

n = int(input("choose the number of integer"))
m = int(input("choose lenght/range of the lst"))
lst = random.sample(range(1, m), n)
print (lst)
# Out:
# choose the number of integer2
# choose lenght/range of the list5
# [4, 3]

# %%
import random
import numpy as np

n = int(input("choose the number of integer"))
m = int(input("choose lenght/range "))
lst = random.sample(range(1, m), n)


import itertools
print(list(itertools.permutations(lst)))
# Out:
# choose the number of integer2
# choose lenght/range 7
# [(1, 3), (3, 1)]

# %%
#challange5

# %%
books = 'ABCDEF'
from itertools import permutations
#nUmber of permutations: 
for b in permutations(books):
    print (b)
# Out:
# ('A', 'B', 'C', 'D', 'F')
# ('A', 'B', 'C', 'F', 'D')
# ('A', 'B', 'D', 'C', 'F')
# ('A', 'B', 'D', 'F', 'C')
# ('A', 'B', 'F', 'C', 'D')
# ('A', 'B', 'F', 'D', 'C')
# ('A', 'C', 'B', 'D', 'F')
# ('A', 'C', 'B', 'F', 'D')
# ('A', 'C', 'D', 'B', 'F')
# ('A', 'C', 'D', 'F', 'B')
# ('A', 'C', 'F', 'B', 'D')
# ('A', 'C', 'F', 'D', 'B')
# ('A', 'D', 'B', 'C', 'F')
# ('A', 'D', 'B', 'F', 'C')
# ('A', 'D', 'C', 'B', 'F')
# ('A', 'D', 'C', 'F', 'B')
# ('A', 'D', 'F', 'B', 'C')
# ('A', 'D', 'F', 'C', 'B')
# ('A', 'F', 'B', 'C', 'D')
# ('A', 'F', 'B', 'D', 'C')
# ('A', 'F', 'C', 'B', 'D')
# ('A', 'F', 'C', 'D', 'B')
# ('A', 'F', 'D', 'B', 'C')
# ('A', 'F', 'D', 'C', 'B')
# ('B', 'A', 'C', 'D', 'F')
# ('B', 'A', 'C', 'F', 'D')
# ('B', 'A', 'D', 'C', 'F')
# ('B', 'A', 'D', 'F', 'C')
# ('B', 'A', 'F', 'C', 'D')
# ('B', 'A', 'F', 'D', 'C')
# ('B', 'C', 'A', 'D', 'F')
# ('B', 'C', 'A', 'F', 'D')
# ('B', 'C', 'D', 'A', 'F')
# ('B', 'C', 'D', 'F', 'A')
# ('B', 'C', 'F', 'A', 'D')
# ...

# %%
book_orientation = 'UD' #can be up or dow, each book 2*2* 2*2* 2*2
from itertools import  product
for p in product(book_orientation, repeat=len(books)):
    print (p)
# Out:
# ('U', 'U', 'U', 'U', 'U')
# ('U', 'U', 'U', 'U', 'D')
# ('U', 'U', 'U', 'D', 'U')
# ('U', 'U', 'U', 'D', 'D')
# ('U', 'U', 'D', 'U', 'U')
# ('U', 'U', 'D', 'U', 'D')
# ('U', 'U', 'D', 'D', 'U')
# ('U', 'U', 'D', 'D', 'D')
# ('U', 'D', 'U', 'U', 'U')
# ('U', 'D', 'U', 'U', 'D')
# ('U', 'D', 'U', 'D', 'U')
# ('U', 'D', 'U', 'D', 'D')
# ('U', 'D', 'D', 'U', 'U')
# ('U', 'D', 'D', 'U', 'D')
# ('U', 'D', 'D', 'D', 'U')
# ('U', 'D', 'D', 'D', 'D')
# ('D', 'U', 'U', 'U', 'U')
# ('D', 'U', 'U', 'U', 'D')
# ('D', 'U', 'U', 'D', 'U')
# ('D', 'U', 'U', 'D', 'D')
# ('D', 'U', 'D', 'U', 'U')
# ('D', 'U', 'D', 'U', 'D')
# ('D', 'U', 'D', 'D', 'U')
# ('D', 'U', 'D', 'D', 'D')
# ('D', 'D', 'U', 'U', 'U')
# ('D', 'D', 'U', 'U', 'D')
# ('D', 'D', 'U', 'D', 'U')
# ('D', 'D', 'U', 'D', 'D')
# ('D', 'D', 'D', 'U', 'U')
# ('D', 'D', 'D', 'U', 'D')
# ('D', 'D', 'D', 'D', 'U')
# ('D', 'D', 'D', 'D', 'D')

# %%
for c in product(permutations(books), product(book_orientation, repeat=len(books))):
    print (C)
